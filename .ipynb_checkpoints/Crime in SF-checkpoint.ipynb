# %%
import re
import scipy
import itertools
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.datasets import load_iris
from sklearn.decomposition import PCA
from sklearn.cross_validation import train_test_split
# %matplotlib inline
pd.options.display.max_rows = 999
# Out:
# /Users/MatthewBarnette/final_project_2/.direnv/python-3.5.0/lib/python3.5/site-packages/matplotlib/__init__.py:872: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))

# %% [markdown]
# plotly, boca, google maps

# %%
sample = pd.read_csv('SF_crime/sampleSubmission.csv')
test = pd.read_csv('SF_crime/test.csv')
test = test.rename(columns={'X': 'Longitude', "Y": "Latitude"})
crime_in_sf = pd.read_csv('SF_crime/train.csv')
crime_in_sf.Dates = pd.to_datetime(crime_in_sf.Dates)
crime_in_sf = crime_in_sf.rename(columns={'X': 'Longitude', "Y": "Latitude"})
crime_in_sf = crime_in_sf.drop(['Resolution', 'Descript'], axis=1)
crime_train, crime_test = train_test_split(crime_in_sf, test_size=.4)

# %%
crime_in_sf[crime_in_sf.Dates.dt.hour == 12].head()
# Out:
#                   Dates        Category  DayOfWeek  PdDistrict  \
# 230 2015-05-13 12:59:00  OTHER OFFENSES  Wednesday  TENDERLOIN
# 231 2015-05-13 12:45:00  SUSPICIOUS OCC  Wednesday    RICHMOND
# 232 2015-05-13 12:37:00    NON-CRIMINAL  Wednesday    NORTHERN
# 233 2015-05-13 12:35:00  SUSPICIOUS OCC  Wednesday    SOUTHERN
# 234 2015-05-13 12:30:00        WARRANTS  Wednesday     TARAVAL
#
#                      Address   Longitude   Latitude
# 230       MASON ST / EDDY ST -122.409313  37.784348
# 231       GEARY BL / 27TH AV -122.486878  37.779992
# 232        IVY ST / GOUGH ST -122.423077  37.777350
# 233      4TH ST / MISSION ST -122.404270  37.784479
# 234  1800 Block of IRVING ST -122.477696  37.763592

# %%
lat_long = crime_in_sf[["Longitude", "Latitude"]]
category_df = pd.get_dummies(crime_in_sf.Category)
day_of_week_df = pd.get_dummies(crime_in_sf.DayOfWeek)
pd_district_df = pd.get_dummies(crime_in_sf.PdDistrict)

# %%
crime_in_sf_k = category_df.join(day_of_week_df)
crime_in_sf_k = crime_in_sf_k.join(pd_district_df)
# crime_in_sf_k = crime_in_sf_k.join(lat_long)

# %%
category_df.sum().plot(kind='barh', figsize=(15,10))

# %%
day_of_week_df.sum().plot(kind='bar', figsize=(20,10))

# %%
pd_district_df.sum().plot(kind='bar', figsize=(20,10))

# %%
pca = PCA(n_components=2)
pca.fit(crime_in_sf_k)
reduced_crime_in_sf = pca.transform(crime_in_sf_k)
kmeans = KMeans(15)

# %%
crime_in_sf_pred = kmeans.fit_predict(reduced_crime_in_sf)

# %%
plt.scatter(kmeans.cluster_centers_[:,0], kmeans.cluster_centers_[:,1], alpha=.5, s=100, color="purple")
plt.scatter(reduced_crime_in_sf[:, 0], reduced_crime_in_sf[:, 1], c=crime_in_sf_pred, cmap="coolwarm", alpha=0.25)
plt.show()

# %%
crime_in_sf['Kgroup'] = crime_in_sf_pred
crime_in_sf = crime_in_sf.sort("Kgroup")
# Out:
# /Users/MatthewBarnette/final_project_2/.direnv/python-3.5.0/lib/python3.5/site-packages/ipykernel/__main__.py:2: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   from ipykernel import kernelapp as app
